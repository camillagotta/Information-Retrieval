# %% [markdown]
# ## POINTWISE MUTUAL INFORMATION - Bigrams Matrix

# %%
import spacy
import string
import re
import pandas as pd
import numpy as np
import seaborn as sns
import random
import pickle
from unidecode import unidecode
import nltk
nltk.download('wordnet')
nltk.download('words')
nltk.download('punkt')

from nltk import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.util import skipgrams
from nltk.corpus import wordnet as wn
from nltk.corpus import stopwords 
from spacy.lang.en import English

from tqdm import tqdm
from gensim import corpora
from gensim.parsing.preprocessing import remove_stopwords
from gensim.parsing.preprocessing import strip_non_alphanum
from gensim.models import CoherenceModel
from sklearn.feature_extraction.text import TfidfVectorizer,CountVectorizer
from nltk.collocations import BigramCollocationFinder, BigramAssocMeasures,TrigramCollocationFinder, TrigramAssocMeasures
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %% [markdown]
# ## PMI - DRUG

# %%
#Reload save pkl file
with open('drug.pkl', 'rb') as f:
    drug = pickle.load(f)

# %%
def get_pmi_value(word1, word2, matrix):
    return matrix.loc[matrix.index == word1, [word2]]

def pmi(df, positive=True):
    cols = df.sum(axis=0)
    total = cols.sum()
    rows = df.sum(axis=1)
    expected = np.outer(rows, cols) / total
    df_pmi = df / expected
    with np.errstate(divide='ignore'):
        df_pmi = np.log(df_pmi)
    df_pmi[np.array(np.isinf(df_pmi))] = 0.0 
    if positive:
        df_pmi[df_pmi < 0] = 0.0
    return df_pmi

def max_cooccurrences(df_column):
    return df_column.idxmax() , df_column.max()

# %%
vectorizer = CountVectorizer(min_df=0.01,  ngram_range=(2,2))
X = vectorizer.fit_transform(drug.Text)

# %%
pmi_drug = pd.DataFrame(X.todense(), columns=vectorizer.vocabulary_)

# %%
asint = pmi_drug.astype(int)
drug_pmi = asint.T.dot(asint)

# %%
drug_pmi.values[[np.arange(drug_pmi.shape[0])]*2] = 0
# Out:
# <ipython-input-9-66051e55d8d7>:1: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   drug_pmi.values[[np.arange(drug_pmi.shape[0])]*2] = 0

# %%
drug_pmi
# Out:
#                     cocaine undercover  conviction felony  minimum sentence  \
# cocaine undercover                   0                  7                33
# conviction felony                    7                  0                 5
# minimum sentence                    33                  5                 0
# received sentence                   12                  1                38
# included offense                     4                  6                 3
# ...                                ...                ...               ...
# statute necessary                    7                  4                11
# giving notice                       16                  2                29
# demurrer sustained                   0                  0                43
# guilty armed                         0                  7                16
# different evidence                  14                  3                20
#
#                     received sentence  included offense  vacate sentence  \
# cocaine undercover                 12                 4               18
# conviction felony                   1                 6                3
# minimum sentence                   38                 3               17
# received sentence                   0                 3                3
# included offense                    3                 0                0
# ...                               ...               ...              ...
# statute necessary                   1                 1                4
# giving notice                       8                 2               12
# demurrer sustained                  3                 0                1
# guilty armed                        2                 0                4
# different evidence                  4                 3                6
#
#                     guilty reasonable  reasonable doubt  evidence sufficient  \
# cocaine undercover                  1                22                   28
# conviction felony                   0                10                    2
# minimum sentence                   24                60                   24
# received sentence                   3                17                    4
# included offense                    0                 4                    0
# ...                               ...               ...                  ...
# statute necessary                   3                16                    1
# giving notice                       9                16                   17
# demurrer sustained                  8                15                   13
# guilty armed                        3                11                    8
# different evidence                  6                43                    6
#
#                     sufficient sustain  ...  unlawful heroin  evidence unable  \
# cocaine undercover                  15  ...               39               14
# conviction felony                    2  ...                5                0
# minimum sentence                    64  ...              120               17
# received sentence                    7  ...                9                7
# included offense                     1  ...                0                2
# ...                                ...  ...              ...              ...
# statute necessary                    0  ...               12                2
# giving notice                       10  ...               34               16
# demurrer sustained                  16  ...                0                0
# guilty armed                         5  ...                0                0
# different evidence                   9  ...               20                8
#
#                     presumption innocence  tried guilty  statute require  \
# cocaine undercover                     15             3               61
# conviction felony                       2             3                3
# minimum sentence                       17            21               64
# received sentence                       6             1               15
# included offense                        5             3                4
# ...                                   ...           ...              ...
# statute necessary                       5             2               39
# giving notice                          17            10               46
# demurrer sustained                      0             0                2
# guilty armed                            0             3                0
# different evidence                      2             3               17
#
#                     statute necessary  giving notice  demurrer sustained  \
# cocaine undercover                  7             16                   0
# conviction felony                   4              2                   0
# minimum sentence                   11             29                  43
# received sentence                   1              8                   3
# included offense                    1              2                   0
# ...                               ...            ...                 ...
# statute necessary                   0              6                   2
# giving notice                       6              0                   8
# demurrer sustained                  2              8                   0
# guilty armed                        6              3                1117
# different evidence                  8              7                  11
#
#                     guilty armed  different evidence
# cocaine undercover             0                  14
# conviction felony              7                   3
# minimum sentence              16                  20
# received sentence              2                   4
# included offense               0                   3
# ...                          ...                 ...
# statute necessary              6                   8
# giving notice                  3                   7
# demurrer sustained          1117                  11
# guilty armed                   0                   9
# different evidence             9                   0
#
# [961 rows x 961 columns]

# %%
drug_occ = pmi(drug_pmi, positive=True)
drug_occ
# Out:
#                     cocaine undercover  conviction felony  minimum sentence  \
# cocaine undercover            0.000000           0.586224          0.000000
# conviction felony             0.586224           0.000000          0.000000
# minimum sentence              0.000000           0.000000          0.000000
# received sentence             0.301831           0.000000          0.669874
# included offense              0.377331           2.357859          0.000000
# ...                                ...                ...               ...
# statute necessary             0.101957           1.117404          0.000000
# giving notice                 0.124287           0.000000          0.000000
# demurrer sustained            0.000000           0.000000          0.000000
# guilty armed                  0.000000           0.373166          0.000000
# different evidence            0.000000           0.000000          0.000000
#
#                     received sentence  included offense  vacate sentence  \
# cocaine undercover           0.301831          0.377331         0.632103
# conviction felony            0.000000          2.357859         0.415406
# minimum sentence             0.669874          0.000000         0.000000
# received sentence            0.000000          0.841322         0.000000
# included offense             0.841322          0.000000         0.000000
# ...                               ...               ...              ...
# statute necessary            0.000000          0.081832         0.218821
# giving notice                0.182813          0.000000         0.513085
# demurrer sustained           0.000000          0.000000         0.000000
# guilty armed                 0.000000          0.000000         0.000000
# different evidence           0.000000          0.202424         0.000000
#
#                     guilty reasonable  reasonable doubt  evidence sufficient  \
# cocaine undercover           0.000000          0.000000             0.857328
# conviction felony            0.000000          0.366408             0.000000
# minimum sentence             0.175196          0.000000             0.000000
# received sentence            0.000000          0.073646             0.000000
# included offense             0.000000          0.000000             0.000000
# ...                               ...               ...                  ...
# statute necessary            0.000000          0.352144             0.000000
# giving notice                0.265450          0.000000             0.644784
# demurrer sustained           0.000000          0.000000             0.000000
# guilty armed                 0.000000          0.000000             0.000000
# different evidence           0.000000          0.362735             0.000000
#
#                     sufficient sustain  ...  unlawful heroin  evidence unable  \
# cocaine undercover            0.114456  ...         0.555792         0.102785
# conviction felony             0.000000  ...         0.076731         0.000000
# minimum sentence              0.780653  ...         0.895086         0.000000
# received sentence             0.103989  ...         0.000000         0.161311
# included offense              0.000000  ...         0.000000         0.082660
# ...                                ...  ...              ...              ...
# statute necessary             0.000000  ...         0.467933         0.000000
# giving notice                 0.000000  ...         0.705038         0.522763
# demurrer sustained            0.000000  ...         0.000000         0.000000
# guilty armed                  0.000000  ...         0.000000         0.000000
# different evidence            0.000000  ...         0.000738         0.000000
#
#                     presumption innocence  tried guilty  statute require  \
# cocaine undercover               0.492235      0.000000         0.473293
# conviction felony                0.052395      0.715644         0.000000
# minimum sentence                 0.000000      0.301856         0.000000
# received sentence                0.327618      0.000000         0.000000
# included offense                 1.319408      1.066367         0.000000
# ...                                   ...           ...              ...
# statute necessary                0.484419      0.000000         1.116776
# giving notice                    0.903845      0.631002         0.477507
# demurrer sustained               0.000000      0.000000         0.000000
# guilty armed                     0.000000      0.000000         0.000000
# different evidence               0.000000      0.000000         0.000000
#
#                     statute necessary  giving notice  demurrer sustained  \
# cocaine undercover           0.101957       0.124287            0.000000
# conviction felony            1.117404       0.000000            0.000000
# minimum sentence             0.000000       0.000000            0.000000
# received sentence            0.000000       0.182813            0.000000
# included offense             0.081832       0.000000            0.000000
# ...                               ...            ...                 ...
# statute necessary            0.000000       0.234253            0.000000
# giving notice                0.234253       0.000000            0.000000
# demurrer sustained           0.000000       0.000000            0.000000
# guilty armed                 0.000000       0.000000            3.425435
# different evidence           0.348263       0.000000            0.000000
#
#                     guilty armed  different evidence
# cocaine undercover      0.000000            0.000000
# conviction felony       0.373166            0.000000
# minimum sentence        0.000000            0.000000
# received sentence       0.000000            0.000000
# included offense        0.000000            0.202424
# ...                          ...                 ...
# statute necessary       0.000000            0.348263
# giving notice           0.000000            0.000000
# demurrer sustained      3.425435            0.000000
# guilty armed            0.000000            0.000000
# different evidence      0.000000            0.000000
#
# [961 rows x 961 columns]

# %%
max_cooccurrences(drug_occ)
# Out:
# (cocaine undercover         manifestly erroneous
#  conviction felony              included offense
#  minimum sentence      improbable unsatisfactory
#  received sentence                sought damages
#  included offense            discretion evidence
#                                  ...
#  statute necessary              offense evidence
#  giving notice               seriousness offense
#  demurrer sustained                 guilty armed
#  guilty armed                 demurrer sustained
#  different evidence        testimony prosecution
#  Length: 961, dtype: object,
#  cocaine undercover    1.991926
#  conviction felony     2.357859
#  minimum sentence      1.993971
#  received sentence     2.114093
#  included offense      4.506532
#                          ...
#  statute necessary     2.163177
#  giving notice         1.727877
#  demurrer sustained    3.425435
#  guilty armed          3.425435
#  different evidence    3.054178
#  Length: 961, dtype: float64)

# %% [markdown]
# ## PMI - WEAPONS

# %%
#Reload save pkl file
with open('weapons.pkl', 'rb') as f:
    weapons = pickle.load(f)

# %%
vectorizer = CountVectorizer(min_df=0.01, ngram_range=(2,2))
X = vectorizer.fit_transform(weapons.Text)

# %%
pmi_weapons = pd.DataFrame(X.todense(), columns=vectorizer.vocabulary_)

# %%
asint = pmi_weapons.astype(int)
weapons_pmi = asint.T.dot(asint)

# %%
weapons_pmi.values[[np.arange(weapons_pmi.shape[0])]*2] = 0
# Out:
# <ipython-input-18-a9ed64a53ec1>:1: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   weapons_pmi.values[[np.arange(weapons_pmi.shape[0])]*2] = 0

# %%
weapons_occ = pmi(weapons_pmi, positive=True)
weapons_occ
# Out:
#                    guilty degree  degree murder  proven guilty  \
# guilty degree           0.000000       0.000000       0.478187
# degree murder           0.000000       0.000000       0.000000
# proven guilty           0.478187       0.000000       0.000000
# guilty reasonable       1.020261       0.000000       1.197307
# reasonable doubt        0.000000       0.751672       0.000000
# ...                          ...            ...            ...
# liable damages          0.265894       0.000000       0.337580
# evidence far            0.000000       0.000000       0.000000
# intent felony           0.000000       0.000000       0.000000
# begun recover           0.413592       0.000000       0.148805
# brought evidence        0.000000       0.000000       0.149933
#
#                    guilty reasonable  reasonable doubt  pled guilty  \
# guilty degree               1.020261          0.000000     1.344625
# degree murder               0.000000          0.751672     0.616070
# proven guilty               1.197307          0.000000     0.107978
# guilty reasonable           0.000000          0.000000     0.984254
# reasonable doubt            0.000000          0.000000     0.043904
# ...                              ...               ...          ...
# liable damages              0.000000          0.000000     0.000000
# evidence far                0.000000          0.211119     0.000000
# intent felony               0.000000          0.000000     0.000000
# begun recover               0.000000          0.000000     0.000000
# brought evidence            0.738527          0.000000     0.000000
#
#                    knew knew  determine testimony  testimony evidence  \
# guilty degree       0.047875             0.031695            0.000000
# degree murder       0.237692             0.000000            0.000000
# proven guilty       0.091389             0.000000            0.907721
# guilty reasonable   0.361530             0.527672            0.341613
# reasonable doubt    0.294015             0.000000            0.000000
# ...                      ...                  ...                 ...
# liable damages      0.000000             0.178770            1.022331
# evidence far        0.655084             0.000000            0.000000
# intent felony       0.018548             0.000000            0.000000
# begun recover       0.000000             0.000000            0.710954
# brought evidence    0.007302             0.000000            0.000000
#
#                    evidence actually  ...  later outside  closeness evidence  \
# guilty degree               0.417662  ...       0.407047            0.346544
# degree murder               0.322642  ...       0.516821            0.000000
# proven guilty               0.343394  ...       0.000000            0.000000
# guilty reasonable           0.000000  ...       0.278869            0.000000
# reasonable doubt            0.101639  ...       0.012097            0.000000
# ...                              ...  ...            ...                 ...
# liable damages              0.734636  ...       0.671905            0.000000
# evidence far                0.000000  ...       0.000000            0.000000
# intent felony               0.000000  ...       0.000000            0.000000
# begun recover               0.000000  ...       0.000000            0.000000
# brought evidence            0.457133  ...       0.196576            0.000000
#
#                    ineffective objective  simply stated  pocket knife  \
# guilty degree                   0.415702       0.063929      0.350928
# degree murder                   0.000000       0.000000      0.000000
# proven guilty                   0.133216       0.135615      0.000000
# guilty reasonable               0.962972       0.000290      0.000000
# reasonable doubt                0.310720       0.000000      0.052605
# ...                                  ...            ...           ...
# liable damages                  0.950543       0.798791      0.623166
# evidence far                    0.000000       0.000000      0.000000
# intent felony                   0.000000       0.000000      0.000000
# begun recover                   0.000000       0.022229      0.166127
# brought evidence                0.234051       0.266303      0.000000
#
#                    liable damages  evidence far  intent felony  begun recover  \
# guilty degree            0.265894      0.000000       0.000000       0.413592
# degree murder            0.000000      0.000000       0.000000       0.000000
# proven guilty            0.337580      0.000000       0.000000       0.148805
# guilty reasonable        0.000000      0.000000       0.000000       0.000000
# reasonable doubt         0.000000      0.211119       0.000000       0.000000
# ...                           ...           ...            ...            ...
# liable damages           0.000000      0.000000       0.000000       0.694198
# evidence far             0.000000      0.000000       3.812543       0.000000
# intent felony            0.000000      3.812543       0.000000       0.000000
# begun recover            0.694198      0.000000       0.000000       0.000000
# brought evidence         0.200004      0.647235       0.425398       0.624334
#
#                    brought evidence
# guilty degree              0.000000
# degree murder              0.000000
# proven guilty              0.149933
# guilty reasonable          0.738527
# reasonable doubt           0.000000
# ...                             ...
# liable damages             0.200004
# evidence far               0.647235
# intent felony              0.425398
# begun recover              0.624334
# brought evidence           0.000000
#
# [1800 rows x 1800 columns]

# %%
max_cooccurrences(weapons_occ)
# Out:
# (guilty degree                 decision admit
#  degree murder         inconsistent statement
#  proven guilty                    stated gave
#  guilty reasonable             decision admit
#  reasonable doubt             noted testimony
#                                ...
#  liable damages       credibility credibility
#  evidence far                   intent felony
#  intent felony              evidence reversal
#  begun recover          favorable prosecution
#  brought evidence         irrelevant evidence
#  Length: 1800, dtype: object,
#  guilty degree        2.336831
#  degree murder        2.856531
#  proven guilty        3.177001
#  guilty reasonable    1.999898
#  reasonable doubt     1.629223
#                         ...
#  liable damages       2.742677
#  evidence far         3.812543
#  intent felony        3.982414
#  begun recover        2.697281
#  brought evidence     1.592183
#  Length: 1800, dtype: float64)

# %% [markdown]
# ## PMI - FINANCE

# %%
#Reload save pkl file
with open('finance.pkl', 'rb') as f:
    finance = pickle.load(f)

# %%
vectorizer = CountVectorizer(min_df=0.01,  ngram_range=(2,2))
X = vectorizer.fit_transform(finance.Text)

# %%
pmi_finance= pd.DataFrame(X.todense(), columns=vectorizer.vocabulary_)

# %%
asint = pmi_finance.astype(int)
finance_pmi = asint.T.dot(asint)

# %%
finance_pmi.values[[np.arange(finance_pmi.shape[0])]*2] = 0
# Out:
# <ipython-input-66-82fdcd6bc2ed>:1: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   finance_pmi.values[[np.arange(finance_pmi.shape[0])]*2] = 0

# %%
finance_pmi
# Out:
#                      necessary necessary  month month  think sufficient  \
# necessary necessary                    0           20                 5
# month month                           20            0                32
# think sufficient                       5           32                 0
# verdict damages                       13           10                 1
# damages damages                        6           17                10
# ...                                  ...          ...               ...
# prove evidence                         6           13                 3
# brought assumpsit                      3            4                 0
# semi annually                          3           11                 6
# shall lawful                           7           18                 4
# shall satisfaction                     5           10                 4
#
#                      verdict damages  damages damages  verdict evidence  \
# necessary necessary               13                6                 3
# month month                       10               17                13
# think sufficient                   1               10                 1
# verdict damages                    0               11                19
# damages damages                   11                0                18
# ...                              ...              ...               ...
# prove evidence                    67               18                13
# brought assumpsit                101               21                18
# semi annually                    104               13                18
# shall lawful                      14                9                 2
# shall satisfaction                 6                3                 7
#
#                      notwithstanding verdict  contrary manifest  \
# necessary necessary                        3                  4
# month month                               11                 24
# think sufficient                           2                 24
# verdict damages                           10                  6
# damages damages                           10                 10
# ...                                      ...                ...
# prove evidence                            10                 24
# brought assumpsit                          6                  1
# semi annually                             14                  3
# shall lawful                              12                 11
# shall satisfaction                         2                 40
#
#                      manifest evidence  evidence decision  ...  \
# necessary necessary                 10                  4  ...
# month month                         41                 14  ...
# think sufficient                    55                 63  ...
# verdict damages                     17                  2  ...
# damages damages                     24                  0  ...
# ...                                ...                ...  ...
# prove evidence                      28                  3  ...
# brought assumpsit                   13                  2  ...
# semi annually                       10                  2  ...
# shall lawful                        54                  0  ...
# shall satisfaction                  42                  6  ...
#
#                      consideration testimony  plea demurrer  \
# necessary necessary                        5             33
# month month                               18             84
# think sufficient                          51            131
# verdict damages                            2             14
# damages damages                            4              9
# ...                                      ...            ...
# prove evidence                             7              5
# brought assumpsit                          2             10
# semi annually                              6              1
# shall lawful                               4             58
# shall satisfaction                        19             58
#
#                      demurrer demurrer  absolutely void  giving refusing  \
# necessary necessary                 13                6               31
# month month                         28               23               59
# think sufficient                    69               17               85
# verdict damages                      2                5               17
# damages damages                      7                5                7
# ...                                ...              ...              ...
# prove evidence                       2               21               18
# brought assumpsit                    9                1                7
# semi annually                        3                2               10
# shall lawful                         0               13               44
# shall satisfaction                  11                6               35
#
#                      prove evidence  brought assumpsit  semi annually  \
# necessary necessary               6                  3              3
# month month                      13                  4             11
# think sufficient                  3                  0              6
# verdict damages                  67                101            104
# damages damages                  18                 21             13
# ...                             ...                ...            ...
# prove evidence                    0                 27             94
# brought assumpsit                27                  0             57
# semi annually                    94                 57              0
# shall lawful                     13                 21              5
# shall satisfaction                3                  2              5
#
#                      shall lawful  shall satisfaction
# necessary necessary             7                   5
# month month                    18                  10
# think sufficient                4                   4
# verdict damages                14                   6
# damages damages                 9                   3
# ...                           ...                 ...
# prove evidence                 13                   3
# brought assumpsit              21                   2
# semi annually                   5                   5
# shall lawful                    0                  11
# shall satisfaction             11                   0
#
# [490 rows x 490 columns]

# %%
max_cooccurrences(finance_pmi)
# Out:
# (necessary necessary         brief argument
#  month month            evidence contention
#  think sufficient            shall continue
#  verdict damages             brief argument
#  damages damages             evidence shown
#                                ...
#  prove evidence              brief argument
#  brought assumpsit          receipt receipt
#  semi annually               brief argument
#  shall lawful                   breach duty
#  shall satisfaction     evidence contention
#  Length: 490, dtype: object,
#  necessary necessary    105
#  month month            409
#  think sufficient       707
#  verdict damages        163
#  damages damages        315
#                        ...
#  prove evidence         292
#  brought assumpsit      185
#  semi annually          144
#  shall lawful           494
#  shall satisfaction     200
#  Length: 490, dtype: int32)

# %% [markdown]
# ## PMI - SEXUAL

# %%
#Reload save pkl file
with open('sexual.pkl', 'rb') as f:
    sexual = pickle.load(f)

# %%
vectorizer = CountVectorizer(min_df=0.01 ,ngram_range=(2,2))
X = vectorizer.fit_transform(sexual.Text)

# %%
pmi= pd.DataFrame(X.todense(), columns=vectorizer.vocabulary_)

# %%
asint = pmi.astype(int)
_pmi = asint.T.dot(asint)

# %%
_pmi.values[[np.arange(_pmi.shape[0])]*2] = 0
# Out:
# <ipython-input-74-6327eb31c154>:1: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   _pmi.values[[np.arange(_pmi.shape[0])]*2] = 0

# %%
_pmi
# Out:
#                        stated following  breach duty  notice stated  \
# stated following                      0           10              0
# breach duty                          10            0              0
# notice stated                         0            0              0
# stated affirm                         1            0              2
# expressly stated                      3            7              2
# ...                                 ...          ...            ...
# prove evidence                        8           32              6
# statute consideration                 6            6              0
# dismissal prejudice                   3            1              1
# clearly shown                         6           13              1
# effect effect                         4           54              0
#
#                        stated affirm  expressly stated  address argument  \
# stated following                   1                 3                15
# breach duty                        0                 7                 6
# notice stated                      2                 2                 3
# stated affirm                      0                 2                 1
# expressly stated                   2                 0                12
# ...                              ...               ...               ...
# prove evidence                     3                 1                 3
# statute consideration              8                 2                19
# dismissal prejudice                0                 3                 6
# clearly shown                      0                 2                12
# effect effect                      0                 0                19
#
#                        reject argument  insufficient establish  \
# stated following                     8                       3
# breach duty                         10                      12
# notice stated                        2                       0
# stated affirm                        0                       0
# expressly stated                     1                       4
# ...                                ...                     ...
# prove evidence                      79                      27
# statute consideration               32                      25
# dismissal prejudice                  0                       1
# clearly shown                        8                       3
# effect effect                      143                      51
#
#                        necessary establish  exercise discretion  ...  \
# stated following                         5                    9  ...
# breach duty                              7                   12  ...
# notice stated                            0                    4  ...
# stated affirm                            0                    2  ...
# expressly stated                         4                    0  ...
# ...                                    ...                  ...  ...
# prove evidence                           2                    7  ...
# statute consideration                    2                    0  ...
# dismissal prejudice                      0                    0  ...
# clearly shown                            1                    1  ...
# effect effect                            3                    7  ...
#
#                        statute unconstitutional  sufficient sustain  \
# stated following                              8                   3
# breach duty                                   9                   3
# notice stated                                 1                   1
# stated affirm                                 4                   2
# expressly stated                              9                   3
# ...                                         ...                 ...
# prove evidence                               16                   0
# statute consideration                        23                   0
# dismissal prejudice                           4                   3
# clearly shown                                 9                   2
# effect effect                                11                   0
#
#                        sustaining demurrer  testimony tending  duty ordinary  \
# stated following                        25                  2              1
# breach duty                             41                  0              7
# notice stated                           10                  0              0
# stated affirm                            4                  3              1
# expressly stated                        17                  2              6
# ...                                    ...                ...            ...
# prove evidence                          42                  0              7
# statute consideration                   22                  0              0
# dismissal prejudice                     16                  0              1
# clearly shown                           26                  0              0
# effect effect                           46                  0              0
#
#                        prove evidence  statute consideration  \
# stated following                    8                      6
# breach duty                        32                      6
# notice stated                       6                      0
# stated affirm                       3                      8
# expressly stated                    1                      2
# ...                               ...                    ...
# prove evidence                      0                    445
# statute consideration             445                      0
# dismissal prejudice                 7                      3
# clearly shown                       1                      0
# effect effect                    6882                   1273
#
#                        dismissal prejudice  clearly shown  effect effect
# stated following                         3              6              4
# breach duty                              1             13             54
# notice stated                            1              1              0
# stated affirm                            0              0              0
# expressly stated                         3              2              0
# ...                                    ...            ...            ...
# prove evidence                           7              1           6882
# statute consideration                    3              0           1273
# dismissal prejudice                      0              3              7
# clearly shown                            3              0              1
# effect effect                            7              1              0
#
# [588 rows x 588 columns]

# %%
max_cooccurrences(_pmi)
# Out:
# (stated following            want prosecution
#  breach duty                       shall hold
#  notice stated            testimony establish
#  stated affirm                shall necessary
#  expressly stated                  shall hold
#                                  ...
#  prove evidence                 effect effect
#  statute consideration    remainder remainder
#  dismissal prejudice         want prosecution
#  clearly shown                     shall hold
#  effect effect                 prove evidence
#  Length: 588, dtype: object,
#  stated following          124
#  breach duty               176
#  notice stated             104
#  stated affirm              38
#  expressly stated          124
#                           ...
#  prove evidence           6882
#  statute consideration    1296
#  dismissal prejudice        73
#  clearly shown             285
#  effect effect            6882
#  Length: 588, dtype: int32)

# %% [markdown]
# ## PMI - DIVORCE

# %%
#Reload save pkl file
with open('divorce.pkl', 'rb') as f:
    divorce = pickle.load(f)

# %%
vectorizer = CountVectorizer(min_df=0.01, ngram_range=(2,2))
X = vectorizer.fit_transform(divorce.Text)

# %%
pmi= pd.DataFrame(X.todense(), columns=vectorizer.vocabulary_)

# %%
asint = pmi.astype(int)
_pmi = asint.T.dot(asint)

# %%
_pmi.values[[np.arange(_pmi.shape[0])]*2] = 0
# Out:
# <ipython-input-81-6327eb31c154>:1: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   _pmi.values[[np.arange(_pmi.shape[0])]*2] = 0

# %%
_pmi
# Out:
#                         according evidence  decision decision  \
# according evidence                       0                  2
# decision decision                        2                  0
# decision evidence                        1                  0
# evidence insufficient                    2                  3
# evidence contrary                        1                  1
# ...                                    ...                ...
# testator gave                            0                  1
# hear determine                           3                  0
# leaving leaving                          0                  0
# making appropriation                     4                  0
# appropriation provided                   0                  0
#
#                         decision evidence  evidence insufficient  \
# according evidence                      1                      2
# decision decision                       0                      3
# decision evidence                       0                      2
# evidence insufficient                   2                      0
# evidence contrary                       0                      5
# ...                                   ...                    ...
# testator gave                           1                      0
# hear determine                          2                      6
# leaving leaving                         3                      0
# making appropriation                    0                      0
# appropriation provided                  1                      0
#
#                         evidence contrary  contrary manifest  \
# according evidence                      1                  0
# decision decision                       1                  0
# decision evidence                       0                  0
# evidence insufficient                   5                  3
# evidence contrary                       0                  0
# ...                                   ...                ...
# testator gave                           1                  0
# hear determine                          1                  2
# leaving leaving                         6                  0
# making appropriation                    1                  1
# appropriation provided                  1                  0
#
#                         manifest evidence  shall shall  ordinary meaning  \
# according evidence                      0            0                 1
# decision decision                       1            1                 4
# decision evidence                       2            4                 1
# evidence insufficient                   1            3                 4
# evidence contrary                       2            3                 8
# ...                                   ...          ...               ...
# testator gave                           0            1                 2
# hear determine                          2            0                 7
# leaving leaving                         0            1                 5
# making appropriation                    0            0                 1
# appropriation provided                  1            1                 3
#
#                         affidavit affidavit  ...  sustaining demurrer  \
# according evidence                        4  ...                    4
# decision decision                         0  ...                    1
# decision evidence                         1  ...                    0
# evidence insufficient                    17  ...                    0
# evidence contrary                         1  ...                    0
# ...                                     ...  ...                  ...
# testator gave                             1  ...                    0
# hear determine                            1  ...                    7
# leaving leaving                           3  ...                    0
# making appropriation                      0  ...                    7
# appropriation provided                    1  ...                    4
#
#                         clearly expressed  competent testimony  \
# according evidence                      2                    1
# decision decision                       1                    1
# decision evidence                      10                   14
# evidence insufficient                   3                    1
# evidence contrary                       5                    0
# ...                                   ...                  ...
# testator gave                           1                    0
# hear determine                          1                    0
# leaving leaving                         2                    0
# making appropriation                    0                    0
# appropriation provided                  0                    1
#
#                         shall testator  entirely different  testator gave  \
# according evidence                   0                   4              0
# decision decision                    0                   2              1
# decision evidence                   41                   7              1
# evidence insufficient                0                   2              0
# evidence contrary                    1                   2              1
# ...                                ...                 ...            ...
# testator gave                        1                   5              0
# hear determine                       0                   2              1
# leaving leaving                      2                   2              0
# making appropriation                 0                   1              0
# appropriation provided               1                   0              0
#
#                         hear determine  leaving leaving  making appropriation  \
# according evidence                   3                0                     4
# decision decision                    0                0                     0
# decision evidence                    2                3                     0
# evidence insufficient                6                0                     0
# evidence contrary                    1                6                     1
# ...                                ...              ...                   ...
# testator gave                        1                0                     0
# hear determine                       0                2                     0
# leaving leaving                      2                0                     1
# making appropriation                 0                1                     0
# appropriation provided               0                1                     0
#
#                         appropriation provided
# according evidence                           0
# decision decision                            0
# decision evidence                            1
# evidence insufficient                        0
# evidence contrary                            1
# ...                                        ...
# testator gave                                0
# hear determine                               0
# leaving leaving                              1
# making appropriation                         0
# appropriation provided                       0
#
# [441 rows x 441 columns]

# %%
max_cooccurrences(_pmi)
# Out:
# (according evidence        sustained demurrer
#  decision decision           affidavit stated
#  decision evidence             shall testator
#  evidence insufficient           void statute
#  evidence contrary            statute require
#                                   ...
#  testator gave               affidavit stated
#  hear determine            sustained demurrer
#  leaving leaving           testator remainder
#  making appropriation        affidavit stated
#  appropriation provided       shown testimony
#  Length: 441, dtype: object,
#  according evidence        65
#  decision decision         17
#  decision evidence         41
#  evidence insufficient     72
#  evidence contrary         26
#                            ..
#  testator gave             39
#  hear determine            69
#  leaving leaving           27
#  making appropriation      22
#  appropriation provided    80
#  Length: 441, dtype: int32)

# %% [markdown]
# ### PMI - BURGLARY

# %%
#Reload save pkl file
with open('burglary.pkl', 'rb') as f:
    burglary = pickle.load(f)

# %%
vectorizer = CountVectorizer(min_df=0.01,  ngram_range=(2,2))
X = vectorizer.fit_transform(burglary.Text)

# %%
pmi= pd.DataFrame(X.todense(), columns=vectorizer.vocabulary_)

# %%
asint = pmi.astype(int)
_pmi = asint.T.dot(asint)

# %%
_pmi.values[[np.arange(_pmi.shape[0])]*2] = 0
# Out:
# <ipython-input-95-6327eb31c154>:1: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   _pmi.values[[np.arange(_pmi.shape[0])]*2] = 0

# %%
_pmi
# Out:
#                      failure comply  convincing evidence  sexual conduct  \
# failure comply                    0                   11              22
# convincing evidence              11                    0               9
# sexual conduct                   22                    9               0
# reasonable basis                 10                    6              41
# contrary manifest                 2                    5              21
# ...                             ...                  ...             ...
# sentence murder                   8                    6              12
# giving refusing                  12                    2              28
# tending prove                    16                   13             164
# burglary larceny                 10                   27             124
# guilty larceny                   13                    3              23
#
#                      reasonable basis  contrary manifest  manifest evidence  \
# failure comply                     10                  2                  5
# convincing evidence                 6                  5                  4
# sexual conduct                     41                 21                 15
# reasonable basis                    0                  2                  7
# contrary manifest                   2                  0                  0
# ...                               ...                ...                ...
# sentence murder                     3                 14                  7
# giving refusing                     6                  0                  3
# tending prove                      10                410                  3
# burglary larceny                    9                344                  0
# guilty larceny                      1                 24                  9
#
#                      evidence believe  accordingly conclude  conduct offense  \
# failure comply                     28                     8               11
# convincing evidence                10                     1                4
# sexual conduct                     53                    39               55
# reasonable basis                   15                     6               14
# contrary manifest                   0                    15                9
# ...                               ...                   ...              ...
# sentence murder                    23                    15               12
# giving refusing                    23                     7                7
# tending prove                       8                    91              165
# burglary larceny                   10                    78               26
# guilty larceny                     30                    28                7
#
#                      evidence reasonable  ...  evidence failure  \
# failure comply                        12  ...                 5
# convincing evidence                    3  ...                 6
# sexual conduct                        19  ...                47
# reasonable basis                       5  ...                10
# contrary manifest                      9  ...                17
# ...                                  ...  ...               ...
# sentence murder                        1  ...                26
# giving refusing                        5  ...                 4
# tending prove                         33  ...               143
# burglary larceny                      24  ...               144
# guilty larceny                         4  ...                14
#
#                      accused evidence  carefully considered  intent intent  \
# failure comply                      6                    37             61
# convincing evidence                 2                    15             58
# sexual conduct                     53                    76             90
# reasonable basis                    3                    10             31
# contrary manifest                  26                     2             20
# ...                               ...                   ...            ...
# sentence murder                    23                    10             53
# giving refusing                     4                    94             37
# tending prove                     573                     1             68
# burglary larceny                  353                     1             53
# guilty larceny                     14                    18             43
#
#                      penalty provided  sentence murder  giving refusing  \
# failure comply                     29                8               12
# convincing evidence                14                6                2
# sexual conduct                     27               12               28
# reasonable basis                    7                3                6
# contrary manifest                   2               14                0
# ...                               ...              ...              ...
# sentence murder                     9                0                1
# giving refusing                    31                1                0
# tending prove                       1              111               23
# burglary larceny                    1               69                0
# guilty larceny                     12               45               14
#
#                      tending prove  burglary larceny  guilty larceny
# failure comply                  16                10              13
# convincing evidence             13                27               3
# sexual conduct                 164               124              23
# reasonable basis                10                 9               1
# contrary manifest              410               344              24
# ...                            ...               ...             ...
# sentence murder                111                69              45
# giving refusing                 23                 0              14
# tending prove                    0              6309             114
# burglary larceny              6309                 0              87
# guilty larceny                 114                87               0
#
# [767 rows x 767 columns]

# %%
max_cooccurrences(_pmi)
# Out:
# (failure comply             reaching decision
#  convincing evidence        reaching decision
#  sexual conduct             reaching decision
#  reasonable basis           reaching decision
#  contrary manifest      conflicting testimony
#                                 ...
#  sentence murder               drawn evidence
#  giving refusing            reaching decision
#  tending prove          conflicting testimony
#  burglary larceny       conflicting testimony
#  guilty larceny         conflicting testimony
#  Length: 767, dtype: object,
#  failure comply           505
#  convincing evidence      176
#  sexual conduct          1179
#  reasonable basis         334
#  contrary manifest       2075
#                         ...
#  sentence murder          440
#  giving refusing          483
#  tending prove          37746
#  burglary larceny       15026
#  guilty larceny           603
#  Length: 767, dtype: int32)
